# %% [markdown]
# # Init SELU Stats
# We will test ```n``` layer ```SELU``` testing theit activation statistics.

# %%
from SELU_NN.SELU import *

# %%
def get_data(num_in, method='kaiming'):
    x, b = torch.randn(num_in), torch.zeros(num_in)
    
    fan_in, fan_out = num_in, num_in
    weights = Weight_Init(fan_in, fan_out)
    
    if method=='kaiming': w = weights.kaiming()
    elif method=='pytorch': w = weights.pytorch()
    elif method=='xaiver': w = weights.xavier()
    elif method=='kaiming2': w = weights.kaiming2()
    elif method=='seluinit': w = weights.seluinit()
    else: w = weights.randn()
        
    return x, w, b

def test_model(num_layers=1, num_in=512, method='kaiming'):
    data = get_data(num_in, method)
    x = data[0]
    model = Model_Optimized(data)
    return model(x, num_layers, plot_stats=True)
# Out:
#   File "<ipython-input-2-18e7c428afe6>", line 8
#     elif method=='pytorch': w = weights.py torch()
#                                                ^
# SyntaxError: invalid syntax

# %%
"""
kaiming
"""
test_model(), test_model(num_layers=10), test_model(num_layers=100)
# Out:
# Iteration: 1
# Initial Activation Stats: (tensor(-0.0049), tensor(0.9833))
# Final Activation Stats: (tensor(0.0102), tensor(1.2853))
# Iteration: 10
# Initial Activation Stats: (tensor(0.0125), tensor(1.0506))
# Final Activation Stats: (tensor(1.2145), tensor(3.4444))
# Iteration: 100
# Initial Activation Stats: (tensor(0.0178), tensor(1.0133))
# Final Activation Stats: (tensor(13.5360), tensor(21.9163))
# ((1, (tensor(-0.0049), tensor(0.9833)), (tensor(0.0102), tensor(1.2853))),
#  (10, (tensor(0.0125), tensor(1.0506)), (tensor(1.2145), tensor(3.4444))),
#  (100, (tensor(0.0178), tensor(1.0133)), (tensor(13.5360), tensor(21.9163))))

# %%
"""
kaiming2
(1./fan_in)
"""
test_model(method='kaiming2'), test_model(num_layers=10, method='kaiming2'), test_model(num_layers=100, method='kaiming2')
# Out:
# Iteration: 1
# Initial Activation Stats: (tensor(-0.0865), tensor(0.9863))
# Final Activation Stats: (tensor(-0.0675), tensor(0.9528))
# Iteration: 10
# Initial Activation Stats: (tensor(0.0005), tensor(1.0136))
# Final Activation Stats: (tensor(-0.0135), tensor(0.9520))
# Iteration: 100
# Initial Activation Stats: (tensor(0.0309), tensor(0.9827))
# Final Activation Stats: (tensor(0.0063), tensor(1.1217))
# ((1, (tensor(-0.0865), tensor(0.9863)), (tensor(-0.0675), tensor(0.9528))),
#  (10, (tensor(0.0005), tensor(1.0136)), (tensor(-0.0135), tensor(0.9520))),
#  (100, (tensor(0.0309), tensor(0.9827)), (tensor(0.0063), tensor(1.1217))))

# %%
"""
pytorch
init.kaiming_uniform_((fan_in, fan_out), a=math.sqrt(5))
"""
test_model(method='pytorch'), test_model(num_layers=10, method='pytorch'), test_model(num_layers=100, method='pytorch')
# Out:
# Iteration: 1
# Initial Activation Stats: (tensor(0.0322), tensor(1.0417))
# Final Activation Stats: (tensor(0.0709), tensor(1.3588))
# Iteration: 10
# Initial Activation Stats: (tensor(0.0134), tensor(0.9685))
# Final Activation Stats: (tensor(1.3843), tensor(3.9327))
# Iteration: 100
# Initial Activation Stats: (tensor(-0.0523), tensor(0.9901))
# Final Activation Stats: (tensor(1533857.), tensor(2178825.))
# ((1, (tensor(0.0322), tensor(1.0417)), (tensor(0.0709), tensor(1.3588))),
#  (10, (tensor(0.0134), tensor(0.9685)), (tensor(1.3843), tensor(3.9327))),
#  (100,
#   (tensor(-0.0523), tensor(0.9901)),
#   (tensor(1533857.), tensor(2178825.))))

# %%
"""
pytorch
init.kaiming_uniform_((fan_in, fan_out), a=math.sqrt(5))
"""
test_model(method='pytorch'), test_model(num_layers=10, method='pytorch'), test_model(num_layers=100, method='pytorch')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-4fa043e36a3a> in <module>
#       3 init.kaiming_uniform_((fan_in, fan_out), a=math.sqrt(5))
#       4 """
# ----> 5 test_model(method='pytorch'), test_model(num_layers=10, method='pytorch'), test_model(num_layers=100, method='pytorch')
#
# <ipython-input-2-888e1886d253> in test_model(num_layers, num_in, method)
#      14
#      15 def test_model(num_layers=1, num_in=512, method='kaiming'):
# ---> 16     data = get_data(num_in, method)
#      17     x = data[0]
#      18     model = Model_Optimized(data)
#
# <ipython-input-2-888e1886d253> in get_data(num_in, method)
#       6
#       7     if method=='kaiming': w = weights.kaiming()
# ----> 8     elif method=='pytorch': w = weights.pytorch()
#       9     elif method=='xaiver': w = weights.xavier()
#      10     elif method=='kaiming2': w = weights.kaiming2()
#
# ~\Documents\Daedalus\SELU_NN\SELU.py in pytorch(self)
#      76     def pytorch(self):
#      77         w = torch.empty(self.fan_in, self.fan_out)
# ---> 78         return nn.init.kaiming_uniform_(w, mode='fan_in', nonlinearity='SeLU')
#      79
#      80     def xavier(self):
#
# ~\Anaconda3\lib\site-packages\torch\nn\init.py in kaiming_uniform_(tensor, a, mode, nonlinearity)
#     313     """
#     314     fan = _calculate_correct_fan(tensor, mode)
# --> 315     gain = calculate_gain(nonlinearity, a)
#     316     std = gain / math.sqrt(fan)
#     317     bound = math.sqrt(3.0) * std  # Calculate uniform bounds from standard deviation
#
# ~\Anaconda3\lib\site-packages\torch\nn\init.py in calculate_gain(nonlinearity, param)
#      69         return math.sqrt(2.0 / (1 + negative_slope ** 2))
#      70     else:
# ---> 71         raise ValueError("Unsupported nonlinearity {}".format(nonlinearity))
#      72
#      73
#
# ValueError: Unsupported nonlinearity SeLU
